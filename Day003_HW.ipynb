# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %% [markdown]
# ## File I/O  讀出來的檔案內容:
# 含 xml的標籤的所有資料
#
# ## xmltodict 讀出來的檔案內容:
# 已將 標籤轉成 dic 結構

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？
# 讀檔案
file_xml = open("./data/64_72hr_CH.xml", encoding='utf-8', mode="r")
xml = file_xml.read()
file_xml.close()

# 解析檔案內容
import xmltodict
weather = dict(xmltodict.parse(xml))

locations = weather['cwbopendata']['dataset']['locations']['location']
for location in locations:
    print(location['locationName'])
print('共有',len(locations),'區')
# Out:
# 鹽埕區
# 鼓山區
# 左營區
# 楠梓區
# 三民區
# 新興區
# 前金區
# 苓雅區
# 前鎮區
# 旗津區
# 小港區
# 鳳山區
# 林園區
# 大寮區
# 大樹區
# 大社區
# 仁武區
# 鳥松區
# 岡山區
# 橋頭區
# 燕巢區
# 田寮區
# 阿蓮區
# 路竹區
# 湖內區
# 茄萣區
# 永安區
# 彌陀區
# 梓官區
# 旗山區
# 美濃區
# 六龜區
# 甲仙區
# 杉林區
# 內門區
# 茂林區
# 桃源區
# 那瑪夏區
# 共有 38 區

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
for location in locations:
    print(location['locationName'], end =' , 第一個時間點:')
    print(location['weatherElement'][0]['time'][0]['dataTime'], end =' , 温度:')
    print(location['weatherElement'][0]['time'][0]['elementValue']['value'])
# Out:
# 鹽埕區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 鼓山區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 左營區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 楠梓區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 三民區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:32
# 新興區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 前金區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 苓雅區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 前鎮區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 旗津區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:32
# 小港區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 鳳山區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 林園區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 大寮區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 大樹區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 大社區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 仁武區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 鳥松區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 岡山區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 橋頭區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:35
# 燕巢區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 田寮區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 阿蓮區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 路竹區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 湖內區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 茄萣區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 永安區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:32
# 彌陀區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:32
# 梓官區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:32
# 旗山區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 美濃區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 六龜區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 甲仙區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:33
# 杉林區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:36
# 內門區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 茂林區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:34
# 桃源區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:31
# 那瑪夏區 , 第一個時間點:2019-06-28T12:00:00+08:00 , 温度:29

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度
print('第一個地區:',locations[0]['locationName'])
eachtimes = locations[0]['weatherElement'][0]['time']
for eachtime in eachtimes:
    print(eachtime['dataTime'], end =' , 温度:')
    print(eachtime['elementValue']['value'])
# Out:
# 第一個地區: 鹽埕區
# 2019-06-28T12:00:00+08:00 , 温度:33
# 2019-06-28T15:00:00+08:00 , 温度:33
# 2019-06-28T18:00:00+08:00 , 温度:32
# 2019-06-28T21:00:00+08:00 , 温度:30
# 2019-06-29T00:00:00+08:00 , 温度:30
# 2019-06-29T03:00:00+08:00 , 温度:29
# 2019-06-29T06:00:00+08:00 , 温度:28
# 2019-06-29T09:00:00+08:00 , 温度:31
# 2019-06-29T12:00:00+08:00 , 温度:32
# 2019-06-29T15:00:00+08:00 , 温度:32
# 2019-06-29T18:00:00+08:00 , 温度:31
# 2019-06-29T21:00:00+08:00 , 温度:30
# 2019-06-30T00:00:00+08:00 , 温度:29
# 2019-06-30T03:00:00+08:00 , 温度:28
# 2019-06-30T06:00:00+08:00 , 温度:28
# 2019-06-30T09:00:00+08:00 , 温度:31
# 2019-06-30T12:00:00+08:00 , 温度:32
# 2019-06-30T15:00:00+08:00 , 温度:32
# 2019-06-30T18:00:00+08:00 , 温度:31
# 2019-06-30T21:00:00+08:00 , 温度:30
# 2019-07-01T00:00:00+08:00 , 温度:29
# 2019-07-01T03:00:00+08:00 , 温度:29
# 2019-07-01T06:00:00+08:00 , 温度:28
# 2019-07-01T09:00:00+08:00 , 温度:31
